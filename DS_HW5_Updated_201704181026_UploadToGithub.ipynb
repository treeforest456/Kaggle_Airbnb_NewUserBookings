# %% [markdown]
# ## Kaggle Competition Experience
#
# ### Airbnb New User Bookings

# %% [markdown]
# #### numerical data
# * merge train data and test data in order to do all the following things to them together. When we need to split them for train and test, then split them.
# * group data into numerical, categorical, text, datetime
# * extract datetime data
# * numerical data interaction, with time date, without time date
# * group data
#
# #### categorical data
# * label encoding
# * one hot encoding
# * leave one out encoding
# * group data
#
# #### train and test
# * create train and test data
# * cross validation
# * predict on test data

# %% [markdown]
# ## <font color = 'blue'>Links</font>

# %% [markdown]
# https://www.kaggle.com/svpons/airbnb-recruiting-new-user-bookings/script-0-8655 <br />
# This is a very simple code and got 0.86
# <br /><br />
# http://brettromero.com/wordpress/data-science-kaggle-walkthrough-cleaning-data/ <br />
# This is someone telling how to clean data
#
# https://www.kaggle.com/c/airbnb-recruiting-new-user-bookings/data <br />
# The original link for this competition

# %% [markdown]
# ## Import Packages

# %%
# ------------------------------ import ------------------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
% matplotlib inline
from sklearn import datasets
from sklearn import svm
from sklearn import cross_validation
from sklearn import tree
from sklearn import svm
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing
import xgboost as xgb

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Step 0 Read Data

# %%
# -------------------------------- 0 read data --------------------------------
sessionRawData = pd.read_csv('sessions.csv')
countriesRawData = pd.read_csv('countries.csv')
ageGenderRawData = pd.read_csv('age_gender_bkts.csv')
trainUser2RawData = pd.read_csv('train_users_2.csv')
testUserRawData = pd.read_csv('test_users.csv')

# %%
# ----------------------------- merge train and test data -----------------------------
# need to merge train data and test data here
# then do the same thing to both of them
train_size = trainUser2RawData.shape[0]
test_size = testUserRawData.shape[0]

fullData = pd.concat([trainUser2RawData, testUserRawData])

# %%
# print trainUser2RawData.shape
# print testUserRawData.shape
# print fullData.shape
# print fullData['country_destination'].isnull().value_counts()
# ----------------------------- check -----------------------------

# %% [markdown]
# ## Step 1 Data Wrangling and exploration

# %%
# -------------------------- have a look at the data --------------------------
print fullData.describe()
print '\n this is the null data in age column\n' , fullData.age.isnull().value_counts()
# Out:
#                  age    signup_flow  timestamp_first_active
# count  158681.000000  275547.000000            2.755470e+05
# mean       47.145310       4.291965            2.013310e+13
# std       142.629468       8.794313            9.146438e+09
# min         1.000000       0.000000            2.009032e+13
# 25%        28.000000       0.000000            2.013040e+13
# 50%        33.000000       0.000000            2.014010e+13
# 75%        42.000000       1.000000            2.014062e+13
# max      2014.000000      25.000000            2.014093e+13
#
#  this is the null data in age column
# False    158681
# True     116866
# Name: age, dtype: int64

# %%
# ---------------------------- 1 data cleansing ----------------------------

# convert all date columns to datetime data type 
fullData['date_account_created'] = pd.to_datetime(fullData.date_account_created)
fullData.timestamp_first_active = pd.to_datetime(fullData.timestamp_first_active.astype('str'))
fullData.date_first_booking = pd.to_datetime(fullData.date_first_booking)


# replace the ones who greater than 100 years old with NaN
for ii in fullData[fullData.age > 100].age.unique():
    fullData.age.replace(to_replace = ii, value = np.nan, inplace = True)
# replace the ones who less than 14 years old with NaN 
for ii in fullData[fullData.age < 14].age.unique():
    fullData.age.replace(to_replace = ii, value = np.nan, inplace = True)
    
# print fullData[fullData.age > 100].age.value_counts() , 'the ones greater than 110 have been replaced'
# print fullData[fullData.age < 14].age.value_counts() , 'the ones less than 10 have been replaced by 0'
# print fullData[fullData.age < 0].age.value_counts() , 'so there is no one less than 0'
# print fullData.age.value_counts()

# %%
print fullData.age.describe()
print '\n' , fullData.age.isnull().value_counts() , '\n'
# print fullData.age.mean() , ' is mean value of age \n'
print fullData.age.median() , ' is median value of age'
# Out:
# count    155932.000000
# mean         36.055043
# std          11.663664
# min          15.000000
# 25%          28.000000
# 50%          33.000000
# 75%          42.000000
# max         100.000000
# Name: age, dtype: float64
#
# False    155932
# True     119615
# Name: age, dtype: int64
#
# 33.0  is median value of age

# %%
# and then we find that there are these mean and median value of age
# I have tried replace the NaN with very big number
# now it's the time I replace them with the average value or median value

# %%
# replace outliers with -1
fullData.age.replace(to_replace = np.nan, value = -1, inplace = True)
print fullData.age.describe()
print '\n' , fullData.age.isnull().value_counts() , '\n'
# Out:
# count    275547.000000
# mean         19.969443
# std          20.354181
# min          -1.000000
# 25%          -1.000000
# 50%          25.000000
# 75%          34.000000
# max         100.000000
# Name: age, dtype: float64
#
# False    275547
# Name: age, dtype: int64

# %%
fullData.head(2)
# Out:
#   affiliate_channel affiliate_provider   age country_destination  \
# 0            direct             direct  -1.0                 NDF
# 1               seo             google  38.0                 NDF
#
#   date_account_created date_first_booking first_affiliate_tracked  \
# 0           2010-06-28                NaT               untracked
# 1           2011-05-25                NaT               untracked
#
#   first_browser first_device_type     gender          id language signup_app  \
# 0        Chrome       Mac Desktop  -unknown-  gxn3p5htnn       en        Web
# 1        Chrome       Mac Desktop       MALE  820tgsjxq7       en        Web
#
#    signup_flow signup_method timestamp_first_active
# 0            0      facebook    2009-03-19 04:32:55
# 1            0      facebook    2009-05-23 17:48:09

# %% [markdown]
# ### check the null value in each columns

# %%
# print fullData.date_first_booking.head(2)
# xxx = fullData.date_first_booking.dt.year
# print xxx.head(2)
for header in fullData:
    print header , '\n' , fullData[header].isnull().value_counts() , '\n'
# Out:
# affiliate_channel
# False    275547
# Name: affiliate_channel, dtype: int64
#
# affiliate_provider
# False    275547
# Name: affiliate_provider, dtype: int64
#
# age
# False    275547
# Name: age, dtype: int64
#
# country_destination
# False    213451
# True      62096
# Name: country_destination, dtype: int64
#
# date_account_created
# False    275547
# Name: date_account_created, dtype: int64
#
# date_first_booking
# True     186639
# False     88908
# Name: date_first_booking, dtype: int64
#
# first_affiliate_tracked
# False    269462
# True       6085
# Name: first_affiliate_tracked, dtype: int64
#
# first_browser
# False    275547
# Name: first_browser, dtype: int64
#
# first_device_type
# False    275547
# Name: first_device_type, dtype: int64
#
# gender
# False    275547
# Name: gender, dtype: int64
#
# id
# False    275547
# Name: id, dtype: int64
#
# language
# False    275547
# Name: language, dtype: int64
#
# signup_app
# False    275547
# Name: signup_app, dtype: int64
#
# signup_flow
# False    275547
# Name: signup_flow, dtype: int64
#
# signup_method
# False    275547
# Name: signup_method, dtype: int64
#
# timestamp_first_active
# False    275547
# Name: timestamp_first_active, dtype: int64

# %% [markdown]
#  From above we can see that there are so many NaN in some of the columns, like <font color = 'red'>age</font> and <font color = 'red'>date_first_booking</font>. Then how should we cope with these NaN data? If we simply replace them with 99999, I think it's not a appropriate way to do so.
#
#  And after this, we know that there is no data about date_first_booking in test data, so what we have here in date_first_booking will not work in the test data, even worse, it will create a massive number of NaN data for us which can really mess with the model and prediction I think.<br />After all, there're only 60k rows in test data, and there're 186k NaN in full data. It could be a huge negtive effect for the model.
#
#  Some null in first_affiliate_tracked, but just 6k of them, and 269k are valid value, so just ignore the null maybe.

# %% [markdown]
# ### Group Original variables

# %%
target = ['country_destination']
id_vars = ['id']
num_vars_org = ['age'
#                 , 'signup_flow'
               ]
datetime_vars_org = ['date_account_created', 'date_first_booking', 'timestamp_first_active']
cat_vars_org = ['affiliate_channel', 'affiliate_provider', 'first_affiliate_tracked', 'first_browser', \
               'first_device_type', 'gender', 'language', 'signup_app', 'signup_method'
               , 'signup_flow'
               ]

# %% [markdown]
# ## Step 2 Feature Engineering

# %% [markdown]
# ## Numerical variables

# %% [markdown]
# ### new numerical variables from date time

# %%
# ---------- created ----------
fullData['created_year'] = fullData['date_account_created'].dt.year
fullData['created_month'] = fullData['date_account_created'].dt.month
fullData['created_day'] = fullData['date_account_created'].dt.day
fullData['created_dayofweek'] = fullData['date_account_created'].dt.dayofweek
fullData['created_dayofyear'] = fullData['date_account_created'].dt.dayofyear
fullData['created_weekofyear'] = fullData['date_account_created'].dt.weekofyear

# ---------- active ----------
fullData['first_active_year'] = fullData['timestamp_first_active'].dt.year
fullData['first_active_month'] = fullData['timestamp_first_active'].dt.month
fullData['first_active_day'] = fullData['timestamp_first_active'].dt.day
fullData['first_active_dayofweek'] = fullData['timestamp_first_active'].dt.dayofweek
fullData['first_active_dayofyear'] = fullData['timestamp_first_active'].dt.dayofyear
fullData['first_active_weekofyear'] = fullData['timestamp_first_active'].dt.weekofyear

# ---------- booking ----------
# fullData['first_booking_year'] = fullData['date_first_booking'].dt.year
# fullData['first_booking_month'] = fullData['date_first_booking'].dt.month
# fullData['first_booking_day'] = fullData['date_first_booking'].dt.day
# fullData['first_booking_dayofweek'] = fullData['date_first_booking'].dt.dayofweek
# fullData['first_booking_dayofyear'] = fullData['date_first_booking'].dt.dayofyear
# fullData['first_booking_weekofyear'] = fullData['date_first_booking'].dt.weekofyear



num_datetime_vars = ['created_year', 'created_month', 'created_day', 'created_dayofweek', 'created_dayofyear', \
                    'created_weekofyear', \
                    'first_active_year', 'first_active_month', 'first_active_day', 'first_active_dayofweek', \
                    'first_active_dayofyear', 'first_active_weekofyear', \
#                     'first_booking_year', 'first_booking_month', 'first_booking_day', 'first_booking_dayofweek', \
#                     'first_booking_dayofyear', 'first_booking_weekofyear'
                    ]

# %% [markdown]
# ### Numerical variables <font color = 'red'>Interaction</font> among date and time variables

# %%
# ---------- active-created ----------
fullData['diff_created_firstActive_year'] = fullData['first_active_year'] - fullData['created_year']
fullData['diff_created_firstActive_month'] = fullData['first_active_month'] - fullData['created_month']
fullData['diff_created_firstActive_day'] = fullData['first_active_day'] - fullData['created_day']

# ---------- booking-active ----------
# fullData['diff_firstActive_booking_year'] = fullData['first_booking_year'] - fullData['first_active_year']
# fullData['diff_firstActive_booking_month'] = fullData['first_booking_month'] - fullData['first_active_month']
# fullData['diff_firstActive_booking_day'] = fullData['first_booking_day'] - fullData['first_active_day']

num_datetime_vars.append('diff_created_firstActive_year')
num_datetime_vars.append('diff_created_firstActive_month')
num_datetime_vars.append('diff_created_firstActive_day')
# num_datetime_vars.append('diff_firstActive_booking_year')
# num_datetime_vars.append('diff_firstActive_booking_month')
# num_datetime_vars.append('diff_firstActive_booking_day')

# %% [markdown]
# ## Categorical variables

# %% [markdown]
# ### One-Hot encoding some of the categorical data

# %%
dummiedMergedCoutriesTrainUses = pd.get_dummies(fullData, columns = cat_vars_org)

# %%
for header in dummiedMergedCoutriesTrainUses:
    print header
# Out:
# age
# country_destination
# date_account_created
# date_first_booking
# id
# timestamp_first_active
# created_year
# created_month
# created_day
# created_dayofweek
# created_dayofyear
# created_weekofyear
# first_active_year
# first_active_month
# first_active_day
# first_active_dayofweek
# first_active_dayofyear
# first_active_weekofyear
# diff_created_firstActive_year
# diff_created_firstActive_month
# diff_created_firstActive_day
# affiliate_channel_api
# affiliate_channel_content
# affiliate_channel_direct
# affiliate_channel_other
# affiliate_channel_remarketing
# affiliate_channel_sem-brand
# affiliate_channel_sem-non-brand
# affiliate_channel_seo
# affiliate_provider_baidu
# affiliate_provider_bing
# affiliate_provider_craigslist
# affiliate_provider_daum
# affiliate_provider_direct
# affiliate_provider_email-marketing
# affiliate_provider_facebook
# affiliate_provider_facebook-open-graph
# affiliate_provider_google
# affiliate_provider_gsp
# affiliate_provider_meetup
# affiliate_provider_naver
# affiliate_provider_other
# affiliate_provider_padmapper
# affiliate_provider_vast
# affiliate_provider_wayn
# affiliate_provider_yahoo
# affiliate_provider_yandex
# first_affiliate_tracked_linked
# first_affiliate_tracked_local ops
# first_affiliate_tracked_marketing
# first_affiliate_tracked_omg
# first_affiliate_tracked_product
# first_affiliate_tracked_tracked-other
# first_affiliate_tracked_untracked
# first_browser_-unknown-
# first_browser_AOL Explorer
# first_browser_Android Browser
# first_browser_Apple Mail
# first_browser_Arora
# first_browser_Avant Browser
# first_browser_BlackBerry Browser
# first_browser_Camino
# first_browser_Chrome
# first_browser_Chrome Mobile
# first_browser_Chromium
# first_browser_CometBird
# first_browser_Comodo Dragon
# first_browser_Conkeror
# first_browser_CoolNovo
# first_browser_Crazy Browser
# first_browser_Epic
# first_browser_Firefox
# first_browser_Flock
# first_browser_Google Earth
# first_browser_Googlebot
# first_browser_IBrowse
# first_browser_IE
# first_browser_IE Mobile
# first_browser_IceDragon
# first_browser_IceWeasel
# first_browser_Iron
# first_browser_Kindle Browser
# first_browser_Maxthon
# first_browser_Mobile Firefox
# first_browser_Mobile Safari
# first_browser_Mozilla
# first_browser_NetNewsWire
# first_browser_Nintendo Browser
# first_browser_OmniWeb
# first_browser_Opera
# first_browser_Opera Mini
# first_browser_Opera Mobile
# first_browser_Outlook 2007
# first_browser_PS Vita browser
# first_browser_Pale Moon
# first_browser_Palm Pre web browser
# first_browser_RockMelt
# first_browser_Safari
# first_browser_SeaMonkey
# first_browser_Silk
# first_browser_SiteKiosk
# first_browser_SlimBrowser
# first_browser_Sogou Explorer
# first_browser_Stainless
# first_browser_TenFourFox
# first_browser_TheWorld Browser
# first_browser_UC Browser
# first_browser_Yandex.Browser
# first_browser_wOSBrowser
# first_device_type_Android Phone
# first_device_type_Android Tablet
# first_device_type_Desktop (Other)
# first_device_type_Mac Desktop
# first_device_type_Other/Unknown
# first_device_type_SmartPhone (Other)
# first_device_type_Windows Desktop
# first_device_type_iPad
# first_device_type_iPhone
# gender_-unknown-
# gender_FEMALE
# gender_MALE
# gender_OTHER
# language_-unknown-
# language_ca
# language_cs
# language_da
# language_de
# language_el
# language_en
# language_es
# language_fi
# language_fr
# language_hr
# language_hu
# language_id
# language_is
# language_it
# language_ja
# language_ko
# language_nl
# language_no
# language_pl
# language_pt
# language_ru
# language_sv
# language_th
# language_tr
# language_zh
# signup_app_Android
# signup_app_Moweb
# signup_app_Web
# signup_app_iOS
# signup_method_basic
# signup_method_facebook
# signup_method_google
# signup_method_weibo
# signup_flow_0
# signup_flow_1
# signup_flow_2
# signup_flow_3
# signup_flow_4
# signup_flow_5
# signup_flow_6
# signup_flow_8
# signup_flow_10
# signup_flow_12
# signup_flow_14
# signup_flow_15
# signup_flow_16
# signup_flow_20
# signup_flow_21
# signup_flow_23
# signup_flow_24
# signup_flow_25

# %%
dummiedMergedCoutriesTrainUses.drop('date_first_booking', axis = 1, inplace = True)

# %%
for header in dummiedMergedCoutriesTrainUses:
    print header
# Out:
# age
# country_destination
# date_account_created
# id
# timestamp_first_active
# created_year
# created_month
# created_day
# created_dayofweek
# created_dayofyear
# created_weekofyear
# first_active_year
# first_active_month
# first_active_day
# first_active_dayofweek
# first_active_dayofyear
# first_active_weekofyear
# diff_created_firstActive_year
# diff_created_firstActive_month
# diff_created_firstActive_day
# affiliate_channel_api
# affiliate_channel_content
# affiliate_channel_direct
# affiliate_channel_other
# affiliate_channel_remarketing
# affiliate_channel_sem-brand
# affiliate_channel_sem-non-brand
# affiliate_channel_seo
# affiliate_provider_baidu
# affiliate_provider_bing
# affiliate_provider_craigslist
# affiliate_provider_daum
# affiliate_provider_direct
# affiliate_provider_email-marketing
# affiliate_provider_facebook
# affiliate_provider_facebook-open-graph
# affiliate_provider_google
# affiliate_provider_gsp
# affiliate_provider_meetup
# affiliate_provider_naver
# affiliate_provider_other
# affiliate_provider_padmapper
# affiliate_provider_vast
# affiliate_provider_wayn
# affiliate_provider_yahoo
# affiliate_provider_yandex
# first_affiliate_tracked_linked
# first_affiliate_tracked_local ops
# first_affiliate_tracked_marketing
# first_affiliate_tracked_omg
# first_affiliate_tracked_product
# first_affiliate_tracked_tracked-other
# first_affiliate_tracked_untracked
# first_browser_-unknown-
# first_browser_AOL Explorer
# first_browser_Android Browser
# first_browser_Apple Mail
# first_browser_Arora
# first_browser_Avant Browser
# first_browser_BlackBerry Browser
# first_browser_Camino
# first_browser_Chrome
# first_browser_Chrome Mobile
# first_browser_Chromium
# first_browser_CometBird
# first_browser_Comodo Dragon
# first_browser_Conkeror
# first_browser_CoolNovo
# first_browser_Crazy Browser
# first_browser_Epic
# first_browser_Firefox
# first_browser_Flock
# first_browser_Google Earth
# first_browser_Googlebot
# first_browser_IBrowse
# first_browser_IE
# first_browser_IE Mobile
# first_browser_IceDragon
# first_browser_IceWeasel
# first_browser_Iron
# first_browser_Kindle Browser
# first_browser_Maxthon
# first_browser_Mobile Firefox
# first_browser_Mobile Safari
# first_browser_Mozilla
# first_browser_NetNewsWire
# first_browser_Nintendo Browser
# first_browser_OmniWeb
# first_browser_Opera
# first_browser_Opera Mini
# first_browser_Opera Mobile
# first_browser_Outlook 2007
# first_browser_PS Vita browser
# first_browser_Pale Moon
# first_browser_Palm Pre web browser
# first_browser_RockMelt
# first_browser_Safari
# first_browser_SeaMonkey
# first_browser_Silk
# first_browser_SiteKiosk
# first_browser_SlimBrowser
# first_browser_Sogou Explorer
# first_browser_Stainless
# first_browser_TenFourFox
# first_browser_TheWorld Browser
# first_browser_UC Browser
# first_browser_Yandex.Browser
# first_browser_wOSBrowser
# first_device_type_Android Phone
# first_device_type_Android Tablet
# first_device_type_Desktop (Other)
# first_device_type_Mac Desktop
# first_device_type_Other/Unknown
# first_device_type_SmartPhone (Other)
# first_device_type_Windows Desktop
# first_device_type_iPad
# first_device_type_iPhone
# gender_-unknown-
# gender_FEMALE
# gender_MALE
# gender_OTHER
# language_-unknown-
# language_ca
# language_cs
# language_da
# language_de
# language_el
# language_en
# language_es
# language_fi
# language_fr
# language_hr
# language_hu
# language_id
# language_is
# language_it
# language_ja
# language_ko
# language_nl
# language_no
# language_pl
# language_pt
# language_ru
# language_sv
# language_th
# language_tr
# language_zh
# signup_app_Android
# signup_app_Moweb
# signup_app_Web
# signup_app_iOS
# signup_method_basic
# signup_method_facebook
# signup_method_google
# signup_method_weibo
# signup_flow_0
# signup_flow_1
# signup_flow_2
# signup_flow_3
# signup_flow_4
# signup_flow_5
# signup_flow_6
# signup_flow_8
# signup_flow_10
# signup_flow_12
# signup_flow_14
# signup_flow_15
# signup_flow_16
# signup_flow_20
# signup_flow_21
# signup_flow_23
# signup_flow_24
# signup_flow_25

# %% [markdown]
# ### Label encoding the target

# %%
LE = preprocessing.LabelEncoder()
labels_transed = LE.fit_transform(dummiedMergedCoutriesTrainUses['country_destination'][:train_size])
    

readyToLearnDataSet = pd.DataFrame(dummiedMergedCoutriesTrainUses)

# %% [markdown]
# ## Step 3 Train the model

# %% [markdown]
# 1. realized that the model cannot learn datetime data type
# 2. 'destination_language' is a mysterious variable that nobody can do things with it

# %%
train_X = readyToLearnDataSet.drop(['country_destination', 'id',\
                                  'date_account_created',\
                                  'timestamp_first_active' ], axis = 1)[:train_size]

train_y = labels_transed.reshape(-1,1)


test_X = readyToLearnDataSet.drop(['country_destination', 'id',\
                                  'date_account_created',\
                                  'timestamp_first_active' ], axis = 1)[train_size:]

test_y = readyToLearnDataSet[['country_destination']][train_size:]

# %%
print train_X.shape , 'train_X shape'
print train_y.shape , 'train_y shape'
print test_X.shape , 'test_X shape'
print test_y.shape , 'test_y shape'

# print test_y.country_destination.value_counts()
# Out:
# (213451, 169) train_X shape
# (213451, 1) train_y shape
# (62096, 169) test_X shape
# (62096, 1) test_y shape

# %%
for header11 in readyToLearnDataSet:
    print readyToLearnDataSet[header11].isnull().value_counts()
# Out:
# False    275547
# Name: age, dtype: int64
# False    213451
# True      62096
# Name: country_destination, dtype: int64
# False    275547
# Name: date_account_created, dtype: int64
# False    275547
# Name: id, dtype: int64
# False    275547
# Name: timestamp_first_active, dtype: int64
# False    275547
# Name: created_year, dtype: int64
# False    275547
# Name: created_month, dtype: int64
# False    275547
# Name: created_day, dtype: int64
# False    275547
# Name: created_dayofweek, dtype: int64
# False    275547
# Name: created_dayofyear, dtype: int64
# False    275547
# Name: created_weekofyear, dtype: int64
# False    275547
# Name: first_active_year, dtype: int64
# False    275547
# Name: first_active_month, dtype: int64
# False    275547
# Name: first_active_day, dtype: int64
# False    275547
# Name: first_active_dayofweek, dtype: int64
# False    275547
# Name: first_active_dayofyear, dtype: int64
# False    275547
# Name: first_active_weekofyear, dtype: int64
# False    275547
# Name: diff_created_firstActive_year, dtype: int64
# False    275547
# Name: diff_created_firstActive_month, dtype: int64
# False    275547
# Name: diff_created_firstActive_day, dtype: int64
# False    275547
# Name: affiliate_channel_api, dtype: int64
# False    275547
# Name: affiliate_channel_content, dtype: int64
# False    275547
# Name: affiliate_channel_direct, dtype: int64
# False    275547
# Name: affiliate_channel_other, dtype: int64
# False    275547
# Name: affiliate_channel_remarketing, dtype: int64
# False    275547
# Name: affiliate_channel_sem-brand, dtype: int64
# False    275547
# Name: affiliate_channel_sem-non-brand, dtype: int64
# False    275547
# Name: affiliate_channel_seo, dtype: int64
# False    275547
# Name: affiliate_provider_baidu, dtype: int64
# False    275547
# Name: affiliate_provider_bing, dtype: int64
# False    275547
# Name: affiliate_provider_craigslist, dtype: int64
# False    275547
# Name: affiliate_provider_daum, dtype: int64
# False    275547
# Name: affiliate_provider_direct, dtype: int64
# False    275547
# Name: affiliate_provider_email-marketing, dtype: int64
# False    275547
# Name: affiliate_provider_facebook, dtype: int64
# False    275547
# Name: affiliate_provider_facebook-open-graph, dtype: int64
# False    275547
# Name: affiliate_provider_google, dtype: int64
# False    275547
# Name: affiliate_provider_gsp, dtype: int64
# False    275547
# Name: affiliate_provider_meetup, dtype: int64
# False    275547
# Name: affiliate_provider_naver, dtype: int64
# False    275547
# Name: affiliate_provider_other, dtype: int64
# False    275547
# Name: affiliate_provider_padmapper, dtype: int64
# False    275547
# Name: affiliate_provider_vast, dtype: int64
# False    275547
# Name: affiliate_provider_wayn, dtype: int64
# False    275547
# Name: affiliate_provider_yahoo, dtype: int64
# False    275547
# Name: affiliate_provider_yandex, dtype: int64
# False    275547
# Name: first_affiliate_tracked_linked, dtype: int64
# False    275547
# Name: first_affiliate_tracked_local ops, dtype: int64
# False    275547
# Name: first_affiliate_tracked_marketing, dtype: int64
# False    275547
# Name: first_affiliate_tracked_omg, dtype: int64
# False    275547
# Name: first_affiliate_tracked_product, dtype: int64
# False    275547
# Name: first_affiliate_tracked_tracked-other, dtype: int64
# False    275547
# Name: first_affiliate_tracked_untracked, dtype: int64
# False    275547
# Name: first_browser_-unknown-, dtype: int64
# False    275547
# Name: first_browser_AOL Explorer, dtype: int64
# False    275547
# Name: first_browser_Android Browser, dtype: int64
# False    275547
# Name: first_browser_Apple Mail, dtype: int64
# False    275547
# Name: first_browser_Arora, dtype: int64
# False    275547
# Name: first_browser_Avant Browser, dtype: int64
# False    275547
# Name: first_browser_BlackBerry Browser, dtype: int64
# False    275547
# Name: first_browser_Camino, dtype: int64
# False    275547
# Name: first_browser_Chrome, dtype: int64
# False    275547
# Name: first_browser_Chrome Mobile, dtype: int64
# False    275547
# Name: first_browser_Chromium, dtype: int64
# False    275547
# Name: first_browser_CometBird, dtype: int64
# False    275547
# Name: first_browser_Comodo Dragon, dtype: int64
# False    275547
# Name: first_browser_Conkeror, dtype: int64
# False    275547
# Name: first_browser_CoolNovo, dtype: int64
# False    275547
# Name: first_browser_Crazy Browser, dtype: int64
# False    275547
# Name: first_browser_Epic, dtype: int64
# False    275547
# Name: first_browser_Firefox, dtype: int64
# False    275547
# Name: first_browser_Flock, dtype: int64
# False    275547
# Name: first_browser_Google Earth, dtype: int64
# False    275547
# Name: first_browser_Googlebot, dtype: int64
# False    275547
# Name: first_browser_IBrowse, dtype: int64
# False    275547
# Name: first_browser_IE, dtype: int64
# False    275547
# Name: first_browser_IE Mobile, dtype: int64
# False    275547
# Name: first_browser_IceDragon, dtype: int64
# False    275547
# Name: first_browser_IceWeasel, dtype: int64
# False    275547
# Name: first_browser_Iron, dtype: int64
# False    275547
# Name: first_browser_Kindle Browser, dtype: int64
# False    275547
# Name: first_browser_Maxthon, dtype: int64
# False    275547
# Name: first_browser_Mobile Firefox, dtype: int64
# False    275547
# Name: first_browser_Mobile Safari, dtype: int64
# False    275547
# Name: first_browser_Mozilla, dtype: int64
# False    275547
# Name: first_browser_NetNewsWire, dtype: int64
# False    275547
# Name: first_browser_Nintendo Browser, dtype: int64
# False    275547
# Name: first_browser_OmniWeb, dtype: int64
# False    275547
# Name: first_browser_Opera, dtype: int64
# False    275547
# Name: first_browser_Opera Mini, dtype: int64
# False    275547
# Name: first_browser_Opera Mobile, dtype: int64
# False    275547
# Name: first_browser_Outlook 2007, dtype: int64
# False    275547
# Name: first_browser_PS Vita browser, dtype: int64
# False    275547
# Name: first_browser_Pale Moon, dtype: int64
# False    275547
# Name: first_browser_Palm Pre web browser, dtype: int64
# False    275547
# Name: first_browser_RockMelt, dtype: int64
# False    275547
# Name: first_browser_Safari, dtype: int64
# False    275547
# Name: first_browser_SeaMonkey, dtype: int64
# False    275547
# Name: first_browser_Silk, dtype: int64
# False    275547
# Name: first_browser_SiteKiosk, dtype: int64
# False    275547
# Name: first_browser_SlimBrowser, dtype: int64
# False    275547
# Name: first_browser_Sogou Explorer, dtype: int64
# False    275547
# Name: first_browser_Stainless, dtype: int64
# False    275547
# Name: first_browser_TenFourFox, dtype: int64
# False    275547
# Name: first_browser_TheWorld Browser, dtype: int64
# False    275547
# Name: first_browser_UC Browser, dtype: int64
# False    275547
# Name: first_browser_Yandex.Browser, dtype: int64
# False    275547
# Name: first_browser_wOSBrowser, dtype: int64
# False    275547
# Name: first_device_type_Android Phone, dtype: int64
# False    275547
# Name: first_device_type_Android Tablet, dtype: int64
# False    275547
# Name: first_device_type_Desktop (Other), dtype: int64
# False    275547
# Name: first_device_type_Mac Desktop, dtype: int64
# False    275547
# Name: first_device_type_Other/Unknown, dtype: int64
# False    275547
# Name: first_device_type_SmartPhone (Other), dtype: int64
# False    275547
# Name: first_device_type_Windows Desktop, dtype: int64
# False    275547
# Name: first_device_type_iPad, dtype: int64
# False    275547
# Name: first_device_type_iPhone, dtype: int64
# False    275547
# Name: gender_-unknown-, dtype: int64
# False    275547
# Name: gender_FEMALE, dtype: int64
# False    275547
# Name: gender_MALE, dtype: int64
# False    275547
# Name: gender_OTHER, dtype: int64
# False    275547
# Name: language_-unknown-, dtype: int64
# False    275547
# Name: language_ca, dtype: int64
# False    275547
# Name: language_cs, dtype: int64
# False    275547
# Name: language_da, dtype: int64
# False    275547
# Name: language_de, dtype: int64
# False    275547
# Name: language_el, dtype: int64
# False    275547
# Name: language_en, dtype: int64
# False    275547
# Name: language_es, dtype: int64
# False    275547
# Name: language_fi, dtype: int64
# False    275547
# Name: language_fr, dtype: int64
# False    275547
# Name: language_hr, dtype: int64
# False    275547
# Name: language_hu, dtype: int64
# False    275547
# Name: language_id, dtype: int64
# False    275547
# Name: language_is, dtype: int64
# False    275547
# Name: language_it, dtype: int64
# False    275547
# Name: language_ja, dtype: int64
# False    275547
# Name: language_ko, dtype: int64
# False    275547
# Name: language_nl, dtype: int64
# False    275547
# Name: language_no, dtype: int64
# False    275547
# Name: language_pl, dtype: int64
# False    275547
# Name: language_pt, dtype: int64
# False    275547
# Name: language_ru, dtype: int64
# False    275547
# Name: language_sv, dtype: int64
# False    275547
# Name: language_th, dtype: int64
# False    275547
# Name: language_tr, dtype: int64
# False    275547
# Name: language_zh, dtype: int64
# False    275547
# Name: signup_app_Android, dtype: int64
# False    275547
# Name: signup_app_Moweb, dtype: int64
# False    275547
# Name: signup_app_Web, dtype: int64
# False    275547
# Name: signup_app_iOS, dtype: int64
# False    275547
# Name: signup_method_basic, dtype: int64
# False    275547
# Name: signup_method_facebook, dtype: int64
# False    275547
# Name: signup_method_google, dtype: int64
# False    275547
# Name: signup_method_weibo, dtype: int64
# False    275547
# Name: signup_flow_0, dtype: int64
# False    275547
# Name: signup_flow_1, dtype: int64
# False    275547
# Name: signup_flow_2, dtype: int64
# False    275547
# Name: signup_flow_3, dtype: int64
# False    275547
# Name: signup_flow_4, dtype: int64
# False    275547
# Name: signup_flow_5, dtype: int64
# False    275547
# Name: signup_flow_6, dtype: int64
# False    275547
# Name: signup_flow_8, dtype: int64
# False    275547
# Name: signup_flow_10, dtype: int64
# False    275547
# Name: signup_flow_12, dtype: int64
# False    275547
# Name: signup_flow_14, dtype: int64
# False    275547
# Name: signup_flow_15, dtype: int64
# False    275547
# Name: signup_flow_16, dtype: int64
# False    275547
# Name: signup_flow_20, dtype: int64
# False    275547
# Name: signup_flow_21, dtype: int64
# False    275547
# Name: signup_flow_23, dtype: int64
# False    275547
# Name: signup_flow_24, dtype: int64
# False    275547
# Name: signup_flow_25, dtype: int64

# %% [markdown]
# ### There is no <font color='red'>'Null'</font> value in this data set now

# %% [markdown]
# ### Implement Scorer

# %%
# ---------------------------- copy from someone else ----------------------------
# https://github.com/davidgasquez/kaggle-airbnb/blob/master/kairbnb/metrics.py
# https://www.kaggle.com/davidgasquez/airbnb-recruiting-new-user-bookings/ndcg-scorer/code

"""Metrics to compute the model performance."""

import numpy as np
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import make_scorer


def dcg_score(y_true, y_score, k=5):
    """Discounted cumulative gain (DCG) at rank K.

    Parameters
    ----------
    y_true : array, shape = [n_samples]
        Ground truth (true relevance labels).
    y_score : array, shape = [n_samples, n_classes]
        Predicted scores.
    k : int
        Rank.

    Returns
    -------
    score : float
    """
    order = np.argsort(y_score)[::-1]
    y_true = np.take(y_true, order[:k])

    gain = 2 ** y_true - 1

    discounts = np.log2(np.arange(len(y_true)) + 2)
    return np.sum(gain / discounts)


def ndcg_score(ground_truth, predictions, k=5):
    """Normalized discounted cumulative gain (NDCG) at rank K.

    Normalized Discounted Cumulative Gain (NDCG) measures the performance of a
    recommendation system based on the graded relevance of the recommended
    entities. It varies from 0.0 to 1.0, with 1.0 representing the ideal
    ranking of the entities.

    Parameters
    ----------
    ground_truth : array, shape = [n_samples]
        Ground truth (true labels represended as integers).
    predictions : array, shape = [n_samples, n_classes]
        Predicted probabilities.
    k : int
        Rank.

    Returns
    -------
    score : float

    Example
    -------
    >>> ground_truth = [1, 0, 2]
    >>> predictions = [[0.15, 0.55, 0.2], [0.7, 0.2, 0.1], [0.06, 0.04, 0.9]]
    >>> score = ndcg_score(ground_truth, predictions, k=2)
    1.0
    >>> predictions = [[0.9, 0.5, 0.8], [0.7, 0.2, 0.1], [0.06, 0.04, 0.9]]
    >>> score = ndcg_score(ground_truth, predictions, k=2)
    0.6666666666
    """
    lb = LabelBinarizer()
    lb.fit(range(len(predictions) + 1))
    T = lb.transform(ground_truth)

    scores = []

    # Iterate over each y_true and compute the DCG score
    for y_true, y_score in zip(T, predictions):
        actual = dcg_score(y_true, y_score, k)
        best = dcg_score(y_true, y_true, k)
        score = float(actual) / float(best)
        scores.append(score)

    return np.mean(scores)


# NDCG Scorer function
ndcg_scorer = make_scorer(ndcg_score, needs_proba=True, k=5)

# %%
clf_xgb = xgb.XGBClassifier(learning_rate = 0.3
                  , n_estimators = 25
                  , max_depth = 6
                  , min_child_weight = 1
                  , subsample = 0.5
                  , colsample_bytree = 0.5
                  , gamma = 1
                  , seed = 1234
                  , nthread = -1
                  , objective='multi:softprob'
                  )
clf_xgb.fit(train_X, train_y)
# Out:
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0
for i in range(len(id_test)):
    idx = id_test[i]
    ids += [idx] * 5
    cts += LE.inverse_transform(np.argsort(preds[i])[::-1])[:5].tolist()
    

# Write csv files as submission
sub = pd.DataFrame(np.column_stack((ids, cts)), columns=['id', 'country'])
sub.to_csv('sub_201710041410.csv',index=False)

# %% [markdown]
# ## Feature importance

# %%
full_vars = []
for header in train_X:
    full_vars.append(header)




feature_importance = pd.DataFrame(sorted(zip(full_vars,clf_xgb.feature_importances_)
                          , key=lambda x: x[1], reverse = True),columns=['feature_name','importance']) 

print (feature_importance.query('importance>0'))
# Out:
#                            feature_name  importance
# 0                     created_dayofyear    0.106512
# 1                                   age    0.098527
# 2                first_active_dayofyear    0.083905
# 3                           created_day    0.063660
# 4                    created_weekofyear    0.040940
# 5                     created_dayofweek    0.037341
# 6                          created_year    0.034417
# 7                      first_active_day    0.033180
# 8                first_active_dayofweek    0.024857
# 9               first_active_weekofyear    0.024857
# 10                    first_active_year    0.024069
# 11        first_device_type_Mac Desktop    0.018221
# 12    first_affiliate_tracked_untracked    0.017658
# 13                  signup_method_basic    0.015971
# 14                        gender_FEMALE    0.014959
# 15                     gender_-unknown-    0.014172
# 16                          gender_MALE    0.013384
# 17                        signup_flow_3    0.013159
# 18                        created_month    0.011697
# 19                       signup_app_Web    0.010348
# 20       first_affiliate_tracked_linked    0.010010
# 21    first_device_type_Windows Desktop    0.009898
# 22              affiliate_channel_other    0.009785
# 23              first_browser_-unknown-    0.009560
# 24                first_browser_Firefox    0.009448
# 25                 first_browser_Safari    0.009448
# 26               signup_method_facebook    0.009448
# 27                 first_browser_Chrome    0.008885
# 28                        signup_flow_0    0.008885
# 29          first_affiliate_tracked_omg    0.008773
# ..                                  ...         ...
# 76            affiliate_provider_meetup    0.001350
# 77                          language_zh    0.001350
# 78                       signup_flow_23    0.001125
# 79        first_browser_Android Browser    0.000900
# 80                          language_ja    0.000900
# 81                          language_pt    0.000900
# 82                       signup_flow_21    0.000787
# 83       diff_created_firstActive_month    0.000562
# 84         affiliate_provider_padmapper    0.000562
# 85             affiliate_provider_yahoo    0.000562
# 86               first_browser_Chromium    0.000562
# 87                          language_nl    0.000562
# 88   affiliate_provider_email-marketing    0.000450
# 89                  first_browser_Opera    0.000450
# 90                        signup_flow_5    0.000450
# 91                          language_no    0.000337
# 92                          language_ru    0.000337
# 93                 signup_method_google    0.000337
# 94    first_affiliate_tracked_marketing    0.000225
# 95           first_browser_AOL Explorer    0.000225
# 96                          language_sv    0.000225
# 97        diff_created_firstActive_year    0.000112
# 98             affiliate_provider_naver    0.000112
# 99    first_affiliate_tracked_local ops    0.000112
# 100    first_browser_BlackBerry Browser    0.000112
# 101                first_browser_Camino    0.000112
# 102             first_browser_IE Mobile    0.000112
# 103              first_browser_RockMelt    0.000112
# 104                  first_browser_Silk    0.000112
# 105                         language_el    0.000112
#
# [106 rows x 2 columns]

# %% [markdown]
# ### Check the prediction

# %%
print y
print le.inverse_transform(y)
# Out:
# [ 7  7 10 ...,  7  7  7]
# ['NDF' 'NDF' 'US' ..., 'NDF' 'NDF' 'NDF']
